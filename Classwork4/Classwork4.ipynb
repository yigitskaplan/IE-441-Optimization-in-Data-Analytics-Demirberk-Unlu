# %%
# Save this colab notebook as name_surname
# You should upload this notebook to the moodle page of the course IE411 as classwork 4
# This is a 10 point classwork

# %%
# Name: Yiğit Şevki
# Surname: Kaplan
# Student ID: 22243810049
# Classwork 4

# %%
# 1)
# Import the following libraries
# Pandas,seaborn,statsmodels.api

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm

# %%
# 2) Import classification_report, confusion_matrix,accuracy_score functions from sklearn.metrics library
#    Import train_test_split from sklearn.model_selection

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %%
# 3 ) Read the dataset called "hear_disease.csv" and call it "hd"

# %%
hd = pd.read_csv('Heart_disease.csv')

# %%
# 4) Write the first 10 observations of hd

# %%
hd.head(10)
# Out:
#    male  age  education  currentSmoker  ...    BMI  heartRate  glucose  TenYearCHD
# 0     1   39        4.0              0  ...  26.97       80.0     77.0           0
# 1     0   46        2.0              0  ...  28.73       95.0     76.0           0
# 2     1   48        1.0              1  ...  25.34       75.0     70.0           0
# 3     0   61        3.0              1  ...  28.58       65.0    103.0           1
# 4     0   46        3.0              1  ...  23.10       85.0     85.0           0
# 5     0   43        2.0              0  ...  30.30       77.0     99.0           0
# 6     0   63        1.0              0  ...  33.11       60.0     85.0           1
# 7     0   45        2.0              1  ...  21.68       79.0     78.0           0
# 8     1   52        1.0              0  ...  26.36       76.0     79.0           0
# 9     1   43        1.0              1  ...  23.61       93.0     88.0           0
#
# [10 rows x 16 columns]

# %%
'''
Please read the explanation about the dataset very carefully

Variables
Each attribute is a potential risk factor. There are both demographic, behavioral and medical risk factors.

Demographic:
• Sex: male or female(Nominal)
• Age: Age of the patient;(Continuous - Although the recorded ages have been truncated to whole numbers, the concept of age is continuous)


Behavioral:
• Current Smoker: whether or not the patient is a current smoker (Nominal)
• Cigs Per Day: the number of cigarettes that the person smoked on average in one day.(can be considered continuous as one can have any number of cigarettes, even half a cigarette.)
Medical( history)

• BP Meds: whether or not the patient was on blood pressure medication (Nominal)
• Prevalent Stroke: whether or not the patient had previously had a stroke (Nominal)
• Prevalent Hyp: whether or not the patient was hypertensive (Nominal)
• Diabetes: whether or not the patient had diabetes (Nominal)
Medical(current)

• Tot Chol: total cholesterol level (Continuous)
• Sys BP: systolic blood pressure (Continuous)
• Dia BP: diastolic blood pressure (Continuous)
• BMI: Body Mass Index (Continuous)
• Heart Rate: heart rate (Continuous - In medical research, variables such as heart rate though in fact discrete, yet are considered continuous because of large number of possible values.)
• Glucose: glucose level (Continuous)

*** Predict variable (desired target) ***

• 10 year risk of coronary heart disease CHD (binary: “1”, means “Yes”, “0” means “No”)'

'''
# Out:
# " \nPlease read the explanation about the dataset very carefully\n\nVariables\nEach attribute is a potential risk factor. There are both demographic, behavioral and medical risk factors.\n\nDemographic:\n• Sex: male or female(Nominal)\n• Age: Age of the patient;(Continuous - Although the recorded ages have been truncated to whole numbers, the concept of age is continuous)\n\n\nBehavioral:\n• Current Smoker: whether or not the patient is a current smoker (Nominal)\n• Cigs Per Day: the number of cigarettes that the person smoked on average in one day.(can be considered continuous as one can have any number of cigarettes, even half a cigarette.)\nMedical( history)\n\n• BP Meds: whether or not the patient was on blood pressure medication (Nominal)\n• Prevalent Stroke: whether or not the patient had previously had a stroke (Nominal)\n• Prevalent Hyp: whether or not the patient was hypertensive (Nominal)\n• Diabetes: whether or not the patient had diabetes (Nominal)\nMedical(current)\n\n• 
# ...

# %%
# 5) Find the number of variables and observations

# %%
hd.shape
# Out:
# (4238, 16)

# %%
# 16 variables, 4238 observations

# %%
# 6) Write the variables which are type int64

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
# X(independent):   male, age, currentSmoker, prevalentStroke, prevalentHyp, diabetes
# Y(dependent):     TenYearCHD

# %%
# 7) Write the variables which have missing variables

# %%
hd.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
# education(105), cigsPerDay(29), BPMeds(53), totChol(50), BMI(19), heartRate(1), glucose(388)

# %%
# 8) Use the following codes to write number of missing observations for each variable
# hd.isna().sum()

# %%
hd.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
# education(105), cigsPerDay(29), BPMeds(53), totChol(50), BMI(19), heartRate(1), glucose(388)

# %%
# 9) Which variable has the highest number of missing observations

# %%
# glucose(388)

# %%
# 10) Use the following codes to fill missing values of each variable with the mean of that variable

# hd['education'] = hd['education'].fillna(hd['education'].mean())
# hd['cigsPerDay'] = hd['cigsPerDay'].fillna(hd['cigsPerDay'].mean())
# hd['BPMeds'] = hd['BPMeds'].fillna(hd['BPMeds'].mean())
# hd['totChol'] = hd['totChol'].fillna(hd['totChol'].mean())
# hd['BMI'] = hd['BMI'].fillna(hd['BMI'].mean())
# hd['heartRate'] = hd['heartRate'].fillna(hd['heartRate'].mean())
# hd['glucose'] = hd['glucose'].fillna(hd['glucose'].mean())

# %%
hd['education'] = hd['education'].fillna(hd['education'].mean())
hd['cigsPerDay'] = hd['cigsPerDay'].fillna(hd['cigsPerDay'].mean())
hd['BPMeds'] = hd['BPMeds'].fillna(hd['BPMeds'].mean())
hd['totChol'] = hd['totChol'].fillna(hd['totChol'].mean())
hd['BMI'] = hd['BMI'].fillna(hd['BMI'].mean())
hd['heartRate'] = hd['heartRate'].fillna(hd['heartRate'].mean())
hd['glucose'] = hd['glucose'].fillna(hd['glucose'].mean())

# %%
# 11) Write number of missing observations for each variable

# %%
hd.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
# 12) Define TenYearCHD as your y variable, the rest will be your X variables

# %%
X = hd.drop(['TenYearCHD'], axis = 1)
Y = hd['TenYearCHD']

# %%
# 13) Write the first 5 observations of y and X to chek if they are correctly defined

# %%
X.head()
# Out:
#    male  age  education  currentSmoker  ...  diaBP    BMI  heartRate  glucose
# 0     1   39        4.0              0  ...   70.0  26.97       80.0     77.0
# 1     0   46        2.0              0  ...   81.0  28.73       95.0     76.0
# 2     1   48        1.0              1  ...   80.0  25.34       75.0     70.0
# 3     0   61        3.0              1  ...   95.0  28.58       65.0    103.0
# 4     0   46        3.0              1  ...   84.0  23.10       85.0     85.0
#
# [5 rows x 15 columns]

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: TenYearCHD, dtype: int64

# %%
# 14) Divide your data set into test and train sets. Test set should contain %30 of the data set. Use random state as 123

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 123)

# %%
# 15) Add constant to X_train and call it X_train_c

# %%
x_train_c = sm.add_constant(x_train)

# %%
# 16) Fit the logistic regression and call it loglr

# %%
loglr = sm.Logit(y_train, x_train_c).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.370428
#          Iterations 7

# %%
#17) Print the summary of the logistic regression

# %%
print(loglr.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:             TenYearCHD   No. Observations:                 2966
# Model:                          Logit   Df Residuals:                     2950
# Method:                           MLE   Df Model:                           15
# Date:                Wed, 03 Dec 2025   Pseudo R-squ.:                  0.1114
# Time:                        07:46:37   Log-Likelihood:                -1098.7
# converged:                       True   LL-Null:                       -1236.5
# Covariance Type:            nonrobust   LLR p-value:                 6.650e-50
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -8.0620      0.815     -9.888      0.000      -9.660      -6.464
# male                0.4887      0.122      4.008      0.000       0.250       0.728
# ...

# %%
#18) Write which coefficients are statistically non-significant

# %%
# education, currentSmoker, BPMeds, prevalentHyp, diabetes, totChol, diaBP, BMI, heartRate

# %%
#19) Get marginal effects of the fitted model and comment on which variable has the highest effects on Y.

# %%
print(loglr.get_margeff().summary())
# Out:
#         Logit Marginal Effects
# ...
# Dep. Variable:             TenYearCHD
# Method:                          dydx
# At:                           overall
# ...
#                      dy/dx    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# male                0.0548      0.014      4.019      0.000       0.028       0.082
# age                 0.0074      0.001      8.806      0.000       0.006       0.009
# education          -0.0033      0.006     -0.516      0.606      -0.016       0.009
# currentSmoker      -0.0096      0.019     -0.499      0.618      -0.047       0.028
# cigsPerDay          0.0030      0.001      4.032      0.000       0.002       0.004
# BPMeds              0.0193      0.029      0.659      0.510      -0.038       0.077
# prevalentStroke     0.1578      0.062      2.547      0.011       0.036       0.279
# ...

# %%
# prevalentStroke. If we increase it by 1, probability of TenYearCHD is increasing by 0.1578.

# %%
# 20) Use loglr model to predict Y in the train test and call it y_hat

# %%
y_hat = loglr.predict(x_train_c)

# %%
x_test_c = sm.add_constant(x_test)
y_hat_t = loglr.predict(x_test_c)

# %%
# 21) Transform y_hat to binary variable and call it y_hat_b

# %%
y_hat_b = (y_hat>0.5).astype(int)
y_hat_t_b = (y_hat_t>0.5).astype(int)

# %%
# 22) Write the first 5 values of y_hat_b

# %%
y_hat_b.head()
# Out:
# 431     0
# 1041    0
# 1798    0
# 2005    0
# 584     0
# dtype: int64

# %%
y_hat_t_b.head()
# Out:
# 1522    0
# 3428    0
# 245     0
# 1049    0
# 2287    0
# dtype: int64

# %%
# 23) Print the coefficient matrix and comment on it

# %%
print(confusion_matrix(y_train, y_hat_b))
# Out:
# [[2519   12]
#  [ 401   34]]

# %%
# T: True, F: False, P: Positive, N: Negative
# 2519(TP)  12(FN)
# 401(FP)   34(TN)

# %%
print(confusion_matrix(y_test, y_hat_t_b))
# Out:
# [[1055    8]
#  [ 190   19]]

# %%
# 1055(TP)  8(FN)
# 190(FP)   19(TN)

# %%
# 24) Calculate the accuracy of the logistic regression

# %%
accuracy = (2519+34)/(2519+12+401+34)
print(accuracy)
# Out:
# 0.8607552258934592

# %%
accuracy_t = (1055+19)/(1055+8+190+19)
print(accuracy_t)
# Out:
# 0.8443396226415094

# %%
# 25) Let X2 be the siginificance variables of the logistic regression

# %%
X2 = X.drop(['education', 'currentSmoker', 'BPMeds', 'prevalentHyp', 'diabetes', 'totChol', 'diaBP', 'BMI', 'heartRate'], axis = 1)

# %%
# 26) Write the first 10 rows of X2

# %%
X2.head(10)
# Out:
#    male  age  cigsPerDay  prevalentStroke  sysBP  glucose
# 0     1   39         0.0                0  106.0     77.0
# 1     0   46         0.0                0  121.0     76.0
# 2     1   48        20.0                0  127.5     70.0
# 3     0   61        30.0                0  150.0    103.0
# 4     0   46        23.0                0  130.0     85.0
# 5     0   43         0.0                0  180.0     99.0
# 6     0   63         0.0                0  138.0     85.0
# 7     0   45        20.0                0  100.0     78.0
# 8     1   52         0.0                0  141.5     79.0
# 9     1   43        30.0                0  162.0     88.0

# %%
# 27) Divide your data set into test and train sets using X2. Test set should contain %30 of the data set. Use random state as 123

# %%
x2_train, x2_test = train_test_split(X2, test_size = 0.3, random_state = 123)

# %%
# 28) Add constant to X2_train and call it X2_train_c

# %%
x2_train_c = sm.add_constant(x2_train)

# %%
# 29) Fit the logistic regression and call it loglr2

# %%
loglr2 = sm.Logit(y_train, x2_train_c).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.371358
#          Iterations 7

# %%
#30) Print the summary of the logistic regression

# %%
print(loglr2.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:             TenYearCHD   No. Observations:                 2966
# Model:                          Logit   Df Residuals:                     2959
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 03 Dec 2025   Pseudo R-squ.:                  0.1092
# Time:                        07:46:37   Log-Likelihood:                -1101.4
# converged:                       True   LL-Null:                       -1236.5
# Covariance Type:            nonrobust   LLR p-value:                 2.160e-55
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -8.5778      0.482    -17.806      0.000      -9.522      -7.634
# male                0.4744      0.118      4.015      0.000       0.243       0.706
# ...

# %%
#31) Write which coefficients are statistically non-significant

# %%
# none of them

# %%
# 32)Use loglr2 model to predict Y in the train test and call it y2_hat

# %%
y2_hat = loglr2.predict(x2_train_c)

# %%
x2_test_c = sm.add_constant(x2_test)
y2_hat_t = loglr2.predict(x2_test_c)

# %%
# 33) Transform y2_hat to binary variable and call it y2_hat_b

# %%
y2_hat_b = (y2_hat>0.5).astype(int)
y2_hat_t_b = (y2_hat_t>0.5).astype(int)

# %%
# 34) Print the coefficient matrix and comment on it

# %%
print(confusion_matrix(y_train, y2_hat_b))
# Out:
# [[2515   16]
#  [ 401   34]]

# %%
print(confusion_matrix(y_test, y2_hat_t_b))
# Out:
# [[1054    9]
#  [ 190   19]]

# %%
# 35) Calculate the accuracy of the second logistic regression

# %%
accuracy_x2 = (2515+34)/(2515+16+401+34)
print(accuracy_x2)
# Out:
# 0.8594066082265678

# %%
accuracy_x2_t = (1054+9)/(1054+9+190+19)
print(accuracy_x2_t)
# Out:
# 0.835691823899371

# %%
# 36) Choose a machine learning we have used so far for classification model of your choice from sklearn library and apply it to the same data set (X2_train_c,X2_test) and compare the accuracy with the logistic regression models.

# %%
from sklearn import svm

# %%
svc = svm.SVC(kernel = 'linear', C=10)

# %%
svc.fit(x2_train, y_train)
# Out:
# SVC(C=10, kernel='linear')

# %%
y_pred = svc.predict(x2_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8333333333333334

# %%
# accuracy with krenel='linear' and C=10 is 0.8333333333333334 which is slightly worse than logistic regression we did.
# Other SVM algorithms might give better result than ours.
# 0.835691823899371 > 0.8333333333333334
